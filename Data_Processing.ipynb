# %% [markdown]
# <a href="https://colab.research.google.com/github/daibacgantay/consumption-in-business/blob/main/Data_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Overview of Data**

# %%
#Read the data file
df = pd.read_excel(r'/content/drive/MyDrive/Junior-1/Sale-data.xlsx')

# %%
# Drop all the uneccessary column
data_use = df.drop(['Thang', 'TotalRevenue', 'TotalProfit', '%Doanh Thu', '%LoiNhuan', 'Ship Date', 'Ship Mode', 'Order Priority', 'Customer Name', 'City', 'State', 'Months', 'Discount' ], axis=1)

# %%
#View all the data
data_use.head()
# Out:
#        Order ID  Order Date  Aging    Product Category            Product  \
# 0   AU-2015-172       42005      8  Auto & Accessories  Car Media Players
# 1  AU-2015-1473       42005      7  Auto & Accessories         Bike Tyres
# 2  AU-2015-1650       42005     10  Auto & Accessories    Car Body Covers
# 3  AU-2015-1999       42005      8  Auto & Accessories  Car Media Players
# 4  AU-2015-2155       42005     10  Auto & Accessories    Car & Bike Care
#
#    Price  Revenue  Quantity  Discount_Value   Profit  Shipping Cost  \
# 0    140  564.880         4            11.20   48.80          4.880
# 1     72  361.440         5             7.20   14.40          1.440
# 2    117  587.530         5            11.70   25.30          2.530
# 3    140  564.880         4            11.20   48.80          4.880
# 4    118  357.092         3             7.08   30.92          3.092
#
#   Customer ID      Segment       Country      Region
# 0    HY-00172     Consumer        Mexico       North
# ...

# %%
#Shape of data
print(data_use.shape)
# Out:
# (51290, 15)

# %%
#Summary about the structure of Data
# All column is enough, therefore, we dont need to remove any null value
data_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          51290 non-null  object
#  1   Order Date        51290 non-null  int64
#  2   Aging             51290 non-null  int64
#  3   Product Category  51290 non-null  object
#  4   Product           51290 non-null  object
#  5   Price             51290 non-null  int64
#  6   Revenue           51290 non-null  float64
#  7   Quantity          51290 non-null  int64
#  8   Discount_Value    51290 non-null  float64
#  9   Profit            51290 non-null  float64
#  10  Shipping Cost     51290 non-null  float64
#  11  Customer ID       51290 non-null  object
#  12  Segment           51290 non-null  object
#  13  Country           51290 non-null  object
#  14  Region            51290 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 5.9+ MB

# %% [markdown]
# ###**Create the new columns**

# %%
region = data_use["Region"]

# %%
data_use['Region_country'] = region

# %%
data_use['longitude'] = region

# %%
data_use['latitude'] = region

# %%
data_use['geo'] = region

# %% [markdown]
# ### **Process data : Map the correct region to each other. Add latitude and longtitude of each region and geomtry of each country**

# %%
mygeo = {
    'Albania': '40.64655281641075,20.167427858529976',#
    'Afghanistan': '33.830488723632016,66.03138202616762',#
    'Algeria':'27.812233010519165,2.5694220562197643',#
    'Angola': '-12.155817791902194,17.886557859291912',#
    'Argentina': '-36.43447998864781,-64.08401167139661',#
    'Armenia': '40.60408484397257,44.65966977686105',#
    'Australia': '-25.944567618224113,134.45363390598288',#
    'Austria' : '47.61384655959853,14.289484199209454',#
    'Azerbaijan': '40.33489925305145,47.77815682907507',
    'Somalia': '5.771759435379465,47.33410718600021',
    'South Africa': '-28.635418518916147,23.98883394282896',
    'South Korea': '36.60535319943733,127.7942888349379',
    'South Sudan': '7.375356261276053,30.375382634737235',
    'Spain': '40.91610655586237,-3.9264389006035003',
    'Sri Lanka': '7.408158185687,80.82434849336084',
    'Sudan': '13.641136599541056,29.946228310227355',
    'Swaziland': '-26.61899049015144,31.49308106072789',
    'Sweden': '64.47376969588262,17.105728747102972',
    'Switzerland': '46.762210006511594,7.9742534977291655',
    'Syria': '34.86897828875156,38.52181325939861',
    'Taiwan': '23.6470571901919,121.02013688764794',
    'Tajikistan': '38.950402395513265,71.09439786627672',
    'Tanzania': '-6.4769905765836455,35.398663156379484',
    'Thailand': '15.011898151701246,101.27653380532996',
    'Togo': '8.770155258448895,1.02219304653147',
    'Trinidad and Tobago': '10.407071490021451, -61.25068812305361',
    'Tunisia': '34.112464383328586,9.555128260957304',
    'Turkey': '38.925913017951416,35.284843732445836',
    'Turkmenistan': '38.83372375524755,59.1447875092735',
    'Uganda': '1.2672995146643586,32.41846179676716',
    'Ukraine': '49.21146616692326,31.287291654664244', #Europe
    'United Arab Emirates': '23.83921558081049,54.23679274787506',
    'United Kingdom': ' 54.046023059660456,-1.9504255421663572',
    'United States': '39.033956525080185,-98.20851957850579',
    'Uruguay': '-32.86394629004666,-55.98027203507806',
    'Uzbekistan': '41.69981260703503,63.56649366605211',
    'Venezuela': '7.207546278589035,-65.85406773730307',
    'Vietnam': '14.276000216720362,108.11110183162606',
    'Yemen': '15.996250762510329,47.81003316042887',
    'Zambia': '-14.385206500174448,27.26672130362465',
    'Zimbabwe': '-19.554765907498137,30.132193217620028'
}

# %%
mydic = {
    'Albania': 'Europe',
    'Afghanistan': 'Asia',
    'Algeria':'Africa',
    'Angola': 'Africa',
    'Argentina': 'South America',
    'Armenia': 'Caucasus',
    'Australia': 'Australia',#Doi
    'Austria' : 'Europe',
    'Azerbaijan': 'Caucasus',
    'Bahrain': 'Middle East',
    'Bangladesh': 'Asia',
    'Barbados': 'Caribbean',
    'Belarus': 'Europe',
    'Belgium': 'Europe',
    'Benin': 'Africa',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Europe',
    'Brazil': 'South America',
    'Bulgaria': 'Europe',
    'Burundi': 'Africa',
    'Cambodia': 'Asia',
    'Cameroon': 'Africa',
    'Canada':'North America',
    'Central African Republic': 'Africa',
    'Chad':'Africa',
    'Chile':'South America',
    'China':'Asia',
    'Colombia':'South America',
    "Cote d'Ivoire": 'Africa',
    'Croatia': 'Europe',
    'Cuba': 'Caribbean',
    'Czech Republic': 'Europe',
    'Democratic Republic of the Congo': 'Africa',
    'Denmark':'Europe',
    'Djibouti':'Africa',
    'Dominican Republic': 'Caribbean',
    'Ecuador': 'South America',
    'Egypt': 'Africa',
    'El Salvador': 'Central America',
    'Equatorial Guinea': 'Africa',
    'Eritrea': 'Africa',
    'Estonia': 'Europe',
    'Ethiopia': 'Africa',
    'Finland': 'Europe',
    'France' : 'Europe',
    'Gabon' : 'Africa',
    'Georgia': 'Caucasus',
    'Germany': 'Europe',
    'Ghana': 'Africa',
    'Guadeloupe': 'Caribbean',
    'Guatemala': 'Central America',
    'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Haiti': 'Caribbean',
    'Honduras': 'South America',
    'Hong Kong': 'Asia',
    'Hungary': 'Europe',
    'India': 'Asia',
    'Indonesia': 'Asia',
    'Iran': 'Middle East',
    'Iraq': 'Middle East',
    'Ireland': 'Europe',
    'Israel': 'Middle East',
    'Italy': 'Europe',
    'Jamaica': 'Caribbean',
    'Japan': 'Asia',
    'Jordan': 'Middle East',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kyrgyzstan':'Asia',
    'Lebanon':'Middle East',
    'Lesotho':'Africa',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'Lithuania': 'Europe',
    'Macedonia': 'Europe',
    'Madagascar': 'Europe',
    'Malaysia': 'Asia',
    'Mali': 'Africa',
    'Martinique': 'Caribbean',
    'Mauritania': 'Africa',
    'Mexico': 'North America',
    'Moldova':'Europe',
    'Mongolia': 'Asia',
    'Montenegro': 'Europe',
    'Morocco': 'Africa',
    'Mozambique': 'Africa',
    'Myanmar (Burma)': 'Asia',
    'Namibia': 'Africa',
    'Nepal': 'Asia',
    'Netherlands': 'Europe',
    'New Zealand': 'New Zealand',#Doi
    'Nicaragua': 'South America',
    'Niger':'Africa',
    'Nigeria': 'Africa',
    'Norway': 'Europe',
    'Pakistan': 'Asia',
    'Panama': 'South America',
    'Papua New Guinea': 'Papua New Guinea',#Doi
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Qatar': 'Middle East',
    'Republic of the Congo': 'Africa',
    'Romania': 'Europe',
    'Russia': 'Europe',
    'Rwanda': 'Africa',
    'Saudi Arabia': 'Middle East',
    'Senegal': 'Africa',
    'Sierra Leone': 'Africa',
    'Singapore': 'Asia',
    'Slovakia': 'Europe',
    'Slovenia': 'Europe',
    'Somalia': 'Africa',
    'South Africa': 'Africa',
    'South Korea': 'Asia',
    'South Sudan': 'Africa',
    'Spain': 'Europe',
    'Sri Lanka': 'Asia',
    'Sudan': 'Africa',
    'Swaziland': 'Africa',
    'Sweden': 'Europe',
    'Switzerland': 'Europe',
    'Syria': 'Middle East',
    'Taiwan': 'Asia',
    'Tajikistan': 'Asia',
    'Tanzania': 'Africa',
    'Thailand': 'Asia',
    'Togo': 'Africa',
    'Trinidad and Tobago': 'Caribbean',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Turkmenistan': 'Asia',
    'Uganda': 'Africa',
    'Ukraine': 'Europe',
    'United Arab Emirates': 'Middle East',
    'United Kingdom': 'Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Asia',
    'Venezuela': 'South America',
    'Vietnam': 'Asia',
    'Yemen': 'Middle East',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa'


}

# %%
for k,v in mydic.items():
  data_use['Region_country'].mask(df['Country'] == k, v, inplace=True)

# %%
mylong = {
    'Central America': '-85.602364',
    'North America': '-100.166666',
    'South America': '-55.491477',
    'Asia': '100.619655',
    'Africa': '34.50852299999997',
    'Europe':'14.4002',
    'Middle East': '39.7332',
    'Caribbean': '-75.818333',
    'Papua New Guinea': '143.9555',
    'Australia': '133.281323',
    'New Zealand': '172.4662705',
    'Caucasus': '44.119332856'

}

# %%
for k,v in mylong.items():
  data_use['longitude'].mask(data_use['Region_country'] == k, v, inplace=True)

# %%
mylat = {
    'Central America': '12.769013',
    'North America': '48.166666',
    'South America': '-8.783195',
    'Asia': '34.047863',
    'Africa': '-8.783195',
    'Europe':'50.0902',
    'Middle East': '30.5852',
    'Caribbean': '14.525556',
    'Papua New Guinea': '-6.31555',
    'Australia': '-26.4390917',
    'New Zealand': '-43.3744881',
    'Caucasus': '42.25666564'

}

# %%
for k,v in mylat.items():
  data_use['latitude'].mask(data_use['Region_country'] == k, v, inplace=True)

# %%
for k,v in mygeo.items():
  data_use['geo'].mask(data_use['Country'] == k, v, inplace=True)

# %%
country = data_use['Country']

# %%
 #Now, let's see the data again
data_use.head()
# Out:
#        Order ID  Order Date  Aging    Product Category            Product  \
# 0   AU-2015-172       42005      8  Auto & Accessories  Car Media Players
# 1  AU-2015-1473       42005      7  Auto & Accessories         Bike Tyres
# 2  AU-2015-1650       42005     10  Auto & Accessories    Car Body Covers
# 3  AU-2015-1999       42005      8  Auto & Accessories  Car Media Players
# 4  AU-2015-2155       42005     10  Auto & Accessories    Car & Bike Care
#
#    Price  Revenue  Quantity  Discount_Value   Profit  Shipping Cost  \
# 0    140  564.880         4            11.20   48.80          4.880
# 1     72  361.440         5             7.20   14.40          1.440
# 2    117  587.530         5            11.70   25.30          2.530
# 3    140  564.880         4            11.20   48.80          4.880
# 4    118  357.092         3             7.08   30.92          3.092
#
#   Customer ID      Segment       Country      Region Region_country  \
# ...

# %%
#Create new file including clean Data for Code web
data_use.to_excel("data_use_for_web.xlsx")
