# %% [markdown]
# <a href="https://colab.research.google.com/github/daibacgantay/consumption-in-business/blob/main/Data_Processing_in_DSDV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'/content/drive/MyDrive/Junior-1/Sale-data.xlsx')

# %%
data_use = df.drop(['Thang', 'TotalRevenue', 'TotalProfit', '%Doanh Thu', '%LoiNhuan', 'Ship Date', 'Ship Mode', 'Order Priority', 'Customer Name', 'City', 'State', 'Months', 'Discount' ], axis=1)

# %%
data_use.head()
# Out:
#        Order ID  Order Date  Aging    Product Category            Product  \
# 0   AU-2015-172       42005      8  Auto & Accessories  Car Media Players
# 1  AU-2015-1473       42005      7  Auto & Accessories         Bike Tyres
# 2  AU-2015-1650       42005     10  Auto & Accessories    Car Body Covers
# 3  AU-2015-1999       42005      8  Auto & Accessories  Car Media Players
# 4  AU-2015-2155       42005     10  Auto & Accessories    Car & Bike Care
#
#    Price  Revenue  Quantity  Discount_Value   Profit  Shipping Cost  \
# 0    140  564.880         4            11.20   48.80          4.880
# 1     72  361.440         5             7.20   14.40          1.440
# 2    117  587.530         5            11.70   25.30          2.530
# 3    140  564.880         4            11.20   48.80          4.880
# 4    118  357.092         3             7.08   30.92          3.092
#
#   Customer ID      Segment       Country      Region Region_country
# ...

# %%
print(data_use.shape)
# Out:
# (51290, 15)

# %%
data_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          51290 non-null  object
#  1   Order Date        51290 non-null  int64
#  2   Aging             51290 non-null  int64
#  3   Product Category  51290 non-null  object
#  4   Product           51290 non-null  object
#  5   Price             51290 non-null  int64
#  6   Revenue           51290 non-null  float64
#  7   Quantity          51290 non-null  int64
#  8   Discount_Value    51290 non-null  float64
#  9   Profit            51290 non-null  float64
#  10  Shipping Cost     51290 non-null  float64
#  11  Customer ID       51290 non-null  object
#  12  Segment           51290 non-null  object
#  13  Country           51290 non-null  object
#  14  Region            51290 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 5.9+ MB

# %%
region = data_use["Region"]

# %%
data_use['Region_country'] = region

# %%
mydic = {
    'Albania': 'Southeast Europe ',
    'Afghanistan': 'Central Asia',
    'Algeria':'North Africa',
    'Angola': 'Southern Africa',
    'Argentina': 'South America',
    'Armenia': 'South Caucasus',
    'Australia': 'Oceania',
    'Austria' : 'Central Europe',
    'Azerbaijan': 'South Caucasus',
    'Bahrain': 'Middle East',
    'Bangladesh': 'South Asia',
    'Barbados': 'Caribbean',
    'Belarus': 'Eastern Europe',
    'Belgium': 'Western Europe',
    'Benin': 'West Africa',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Southeast Europe',
    'Brazil': 'South America',
    'Bulgaria': 'Southeast Europe',
    'Burundi': 'East Africa',
    'Cambodia': 'Southeast Asia',
    'Cameroon': 'Central Africa',
    'Canada':'North America',
    'Central African Republic': 'Central Africa',
    'Chad':'Central Africa',
    'Chile':'South America',
    'China':'East Asia',
    'Colombia':'South America',
    'Cote dIvoire': 'West Africa',
    'Croatia': 'Southeast Europe',
    'Cuba': 'Caribbean',
    'Czech Republic': 'Central Europe',
    'Democratic Republic of the Congo': 'Central Africa',
    'Denmark':'Northern Europe',
    'Djibouti':'Horn of Africa',
    'Dominican Republic': 'Caribbean',
    'Ecuador': 'South America',
    'Egypt': 'North Africa',
    'EI Salvador': 'Central America',
    'Equatorial Guinea': 'Central Africa',
    'Eritrea': 'Horn of Africa',
    'Estonia': 'Northern Europe',
    'Ethiopia': 'Horn of Africa',
    'Finland': 'Northern Europe',
    'France' : 'Western Europe',
    'Gabon' : 'Central Africa',
    'Georgia': 'South Caucasus',
    'Germany': 'Central Europe',
    'Ghana': 'West Africa',
    'Guadeloupe': 'Caribbean',
    'Guatemala': 'South America',
    'Guinea': 'West Africa',
    'Guinea-Bissau': 'West Africa',
    'Haiti': 'Caribbean',
    'Honduras': 'Central America',
    'Hong Kong': 'East Asia',
    'Hungary': 'Central Europe',
    'India': 'South Asia',
    'Indonesia': 'Southeast Asia',
    'Iran': 'Middle East',
    'Iraq': 'Middle East',
    'Ireland': 'Northwestern Europe',
    'Israel': 'Middle East',
    'Italy': 'Southern Europe',
    'Jamaica': 'Caribbean',
    'Japan': 'East Asia',
    'Jordan': 'Middle East',
    'Kazakhstan': 'Central Asia',
    'Kenya': 'East Africa',
    'Kyrgyzstan':'Central Asia',
    'Lebanon':'Middle East',
    'Lesotho':'Southern Africa',
    'Liberia': 'West Africa',
    'Libya': 'North Africa',
    'Lithuania': 'Northern Europe',
    'Macedonia': 'Southeast Europe',
    'Madagascar': 'Southeast Europe',
    'Malaysia': 'Southeast Asia',
    'Mali': 'West Africa',
    'Martinique': 'Caribbean',
    'Mauritania': 'Northwest Africa',
    'Mexico': 'North America',
    'Moldova':'Eastern Europe',
    'Mongolia': 'Central Asia',
    'Montenegro': 'Southeastern Europe',
    'Morocco': 'North Africa',
    'Mozambique': 'Southeast Africa',
    'Myanmar (Burma)': 'Southeast Asia',
    'Namibia': 'southwestern Africa',
    'Nepal': 'South Asia',
    'Netherlands': 'Northwestern Europe',
    'New Zealand': 'Oceania',
    'Nicaragua': 'Central America',
    'Niger':'West Africa',
    'Nigeria': 'West Africa',
    'Norway': 'Northern Europe',
    'Pakistan': 'South Asia',
    'Panama': 'Central America',
    'Papua New Guinea': 'Pacific Ocean',
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Southeast Asia',
    'Poland': 'Central Europe',
    'Portugal': 'Southern Europe',
    'Qatar': 'Middle East',
    'Republic of the Congo': 'Central Africa',
    'Romania': ' Eastern Europe',
    'Russia': 'Eastern Europe',
    'Rwanda': 'Central Africa',
    'Saudi Arabia': 'Middle East',
    'Senegal': 'West Africa',
    'Sierra Leone': 'West Africa',
    'Singapore': 'Southeast Asia',
    'Slovakia': 'Central Europe',
    'Slovenia': 'Central Europe',
    'Somalia': 'Horn of Africa',
    'South Africa': 'South Africa',
    'South Korea': 'East Asia',
    'South Sudan': 'Central Africa',
    'Spain': 'Southern Europe',
    'Sri Lanka': 'South Asia',
    'Sudan': 'Northeast Africa',
    'Swaziland': 'Southern Africa',
    'Sweden': 'Northern Europe',
    'Switzerland': 'Central Europe',
    'Syria': 'Middle East',
    'Taiwan': 'East Asia',
    'Tajikistan': 'Central Asia',
    'Tanzania': 'East Africa',
    'Thailand': 'Southeast Asia',
    'Togo': 'West Africa',
    'Trinidad and Tobago': 'Caribbean',
    'Tunisia': 'North Africa',
    'Turkey': 'Western Asia',
    'Turkmenistan': 'Central Asia',
    'Uganda': 'East Africa',
    'Ukraine': 'Middle East',
    'United Arab Emirates': 'Middle East',
    'United Kingdom': 'Northwestern Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Central Asia',
    'Venezuela': 'South America',
    'Vietnam': 'Southeast Asia',
    'Yemen': 'Middle East',
    'Zambia': 'Eastern Africa',
    'Zimbabwe': 'Eastern Africa'


}

# %%
mydic = {
    'Albania': 'Europe',
    'Afghanistan': 'Asia',
    'Algeria':'Africa',
    'Angola': 'Africa',
    'Argentina': 'South America',
    'Armenia': 'Caucasus',
    'Australia': 'Australia',#Doi
    'Austria' : 'Europe',
    'Azerbaijan': 'Caucasus',
    'Bahrain': 'Middle East',
    'Bangladesh': 'Asia',
    'Barbados': 'Caribbean',
    'Belarus': 'Europe',
    'Belgium': 'Europe',
    'Benin': 'Africa',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Europe',
    'Brazil': 'South America',
    'Bulgaria': 'Europe',
    'Burundi': 'Africa',
    'Cambodia': 'Asia',
    'Cameroon': 'Africa',
    'Canada':'North America',
    'Central African Republic': 'Africa',
    'Chad':'Africa',
    'Chile':'South America',
    'China':'Asia',
    'Colombia':'South America',
    'Cote dIvoire': 'Africa',
    'Croatia': 'Europe',
    'Cuba': 'Caribbean',
    'Czech Republic': 'Europe',
    'Democratic Republic of the Congo': 'Africa',
    'Denmark':'Europe',
    'Djibouti':'Africa',
    'Dominican Republic': 'Caribbean',
    'Ecuador': 'South America',
    'Egypt': 'Africa',
    'El Salvador': 'Central America',
    'Equatorial Guinea': 'Africa',
    'Eritrea': 'Africa',
    'Estonia': 'Europe',
    'Ethiopia': 'Africa',
    'Finland': 'Europe',
    'France' : 'Europe',
    'Gabon' : 'Africa',
    'Georgia': 'Caucasus',
    'Germany': 'Europe',
    'Ghana': 'Africa',
    'Guadeloupe': 'Caribbean',
    'Guatemala': 'Central America',
    'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Haiti': 'Caribbean',
    'Honduras': 'South America',
    'Hong Kong': 'Asia',
    'Hungary': 'Europe',
    'India': 'Asia',
    'Indonesia': 'Asia',
    'Iran': 'Middle East',
    'Iraq': 'Middle East',
    'Ireland': 'Europe',
    'Israel': 'Middle East',
    'Italy': 'Europe',
    'Jamaica': 'Caribbean',
    'Japan': 'Asia',
    'Jordan': 'Middle East',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kyrgyzstan':'Asia',
    'Lebanon':'Middle East',
    'Lesotho':'Africa',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'Lithuania': 'Europe',
    'Macedonia': 'Europe',
    'Madagascar': 'Europe',
    'Malaysia': 'Asia',
    'Mali': 'Africa',
    'Martinique': 'Caribbean',
    'Mauritania': 'Africa',
    'Mexico': 'North America',
    'Moldova':'Europe',
    'Mongolia': 'Asia',
    'Montenegro': 'Europe',
    'Morocco': 'Africa',
    'Mozambique': 'Africa',
    'Myanmar (Burma)': 'Asia',
    'Namibia': 'Africa',
    'Nepal': 'Asia',
    'Netherlands': 'Europe',
    'New Zealand': 'New Zealand',#Doi
    'Nicaragua': 'South America',
    'Niger':'Africa',
    'Nigeria': 'Africa',
    'Norway': 'Europe',
    'Pakistan': 'Asia',
    'Panama': 'South America',
    'Papua New Guinea': 'Papua New Guinea',#Doi
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Qatar': 'Middle East',
    'Republic of the Congo': 'Africa',
    'Romania': 'Europe',
    'Russia': 'Europe',
    'Rwanda': 'Africa',
    'Saudi Arabia': 'Middle East',
    'Senegal': 'Africa',
    'Sierra Leone': 'Africa',
    'Singapore': 'Asia',
    'Slovakia': 'Europe',
    'Slovenia': 'Europe',
    'Somalia': 'Africa',
    'South Africa': 'Africa',
    'South Korea': 'Asia',
    'South Sudan': 'Africa',
    'Spain': 'Europe',
    'Sri Lanka': 'Asia',
    'Sudan': 'Africa',
    'Swaziland': 'Africa',
    'Sweden': 'Europe',
    'Switzerland': 'Europe',
    'Syria': 'Middle East',
    'Taiwan': 'Asia',
    'Tajikistan': 'Asia',
    'Tanzania': 'Africa',
    'Thailand': 'Asia',
    'Togo': 'Africa',
    'Trinidad and Tobago': 'Caribbean',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Turkmenistan': 'Asia',
    'Uganda': 'Africa',
    'Ukraine': 'Middle East',
    'United Arab Emirates': 'Middle East',
    'United Kingdom': 'Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Asia',
    'Venezuela': 'South America',
    'Vietnam': 'Asia',
    'Yemen': 'Middle East',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa'


}

# %%
for k,v in mydic.items():
  data_use['Region_country'].mask(df['Country'] == k, v, inplace=True)

# %%
data_use.corr()
# Out:
# <ipython-input-12-b982aa1b6af8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_use.corr()
#                  Order Date     Aging     Price   Revenue  Quantity  \
# Order Date         1.000000 -0.002043  0.001732  0.003166  0.002911
# Aging             -0.002043  1.000000  0.014840  0.010042 -0.002432
# Price              0.001732  0.014840  1.000000  0.645111 -0.000512
# Revenue            0.003166  0.010042  0.645111  1.000000  0.703373
# Quantity           0.002911 -0.002432 -0.000512  0.703373  1.000000
# Discount_Value     0.007300  0.004802  0.480869  0.758497  0.544008
# Profit             0.000582  0.015236  0.921502  0.473888 -0.176294
# Shipping Cost      0.000582  0.015236  0.921502  0.473888 -0.176294
#
#                  Discount_Value     Profit  Shipping Cost
# ...

# %%
data_use.to_excel("data_use.xlsx")
